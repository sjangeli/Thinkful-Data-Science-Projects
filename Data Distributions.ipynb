# %%
# Assignment: 

# 1. Generate a random variable with 100 datapoints using the code distributionvar = np.random.distributionname([arguments], 100), 
#    replacing distributionvar with an appropriate variable name and distributionname with the name of the distribution you’ve chosen, and filling 
#    in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, 
#    go back to the “Other Distributions” assignment for examples of code to use as a starting point.

# 2. Graph the variable using a histogram.

# 3. Compute the mean and standard deviation and plot them as vertical lines on the histogram.

# 4. Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics 
#    of the distributions that could be usefully described using the mean and/or standard deviation?

# Additionally:

# 5. Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and a 
#    standard deviation of 1.

# 6. Add them together to create a third variable.

# 7. Graph the third variable using a histogram.

# 8. Compute the mean and standard deviation and plot them as vertical lines on the histogram.

# 9. Evaluate the descriptive statistics against the data.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
# First Distribution: Beta

beta = np.random.beta(1, 2, 100)
plt.hist(beta)
beta_mean = np.mean(beta)
beta_std = np.std(beta)
print("Mean:", beta_mean)
print("Standard Deviation:", beta_std)

plt.hist(beta, color='blue')
plt.axvline(x=beta_mean, color='red')
plt.axvline(x=beta_mean+beta_std, color='yellow')
plt.axvline(x=beta_mean-beta_std, color='yellow')
beta_pd = pd.DataFrame(beta)
beta_pd.describe()
plt.show()
# Out:
# Mean: 0.31001797699092476
# Standard Deviation: 0.22732007301487964

# %%
# Second Distribution: Gumbel

gumbel = np.random.gumbel(0, 1, 100)
plt.hist(gumbel)
gumbel_mean = np.mean(gumbel)
gumbel_std = np.std(gumbel)
print("Mean:", gumbel_mean)
print("Standard Deviation:", gumbel_std)

plt.hist(gumbel, color='blue')
plt.axvline(x=gumbel_mean, color='red')
plt.axvline(x=gumbel_mean+gumbel_std, color='yellow')
plt.axvline(x=gumbel_mean-gumbel_std, color='yellow')
gumbel_pd = pd.DataFrame(gumbel)
gumbel_pd.describe()
plt.show()
# Out:
# Mean: 0.60957800508158
# Standard Deviation: 1.3543290183096397

# %%
# Third Distribution: Rayleigh

rayleigh = np.random.rayleigh(1, 100)
plt.hist(rayleigh)
rayleigh_mean = np.mean(rayleigh)
rayleigh_std = np.std(rayleigh)
print("Mean:", rayleigh_mean)
print("Standard Deviation:", rayleigh_std)

plt.hist(rayleigh, color='blue')
plt.axvline(x=rayleigh_mean, color='red')
plt.axvline(x=rayleigh_mean+rayleigh_std, color='yellow')
plt.axvline(x=rayleigh_mean-rayleigh_std, color='yellow')
rayleigh_pd = pd.DataFrame(rayleigh)
rayleigh_pd.describe()
plt.show()
# Out:
# Mean: 1.2489522855889188
# Standard Deviation: 0.6606326415909847

# %%
# Fourth Distribution: Laplace

laplace = np.random.laplace(0, 1, 100)
plt.hist(laplace)
laplace_mean = np.mean(laplace)
laplace_std = np.std(laplace)
print("Mean:", laplace_mean)
print("Standard Deviation:", laplace_std)

plt.hist(laplace, color='blue')
plt.axvline(x=laplace_mean, color='red')
plt.axvline(x=laplace_mean+laplace_std, color='yellow')
plt.axvline(x=laplace_mean-laplace_std, color='yellow')
laplace_pd = pd.DataFrame(laplace)
laplace_pd.describe()
plt.show()
# Out:
# Mean: 0.011391926773507482
# Standard Deviation: 1.6176364219367096

# %%
# Fifth Distribution: Pareto

pareto = np.random.pareto(5, 100)
plt.hist(pareto)
pareto_mean = np.mean(pareto)
pareto_std = np.std(pareto)
print("Mean:", pareto_mean)
print("Standard Deviation:", pareto_std)

plt.hist(pareto, color='blue')
plt.axvline(x=pareto_mean, color='red')
plt.axvline(x=pareto_mean+pareto_std, color='yellow')
plt.axvline(x=pareto_mean-pareto_std, color='yellow')
pareto_pd = pd.DataFrame(pareto)
pareto_pd.describe()
plt.show()
# Out:
# Mean: 0.2401082118063943
# Standard Deviation: 0.26571221795789207

# %%
# Sixth Distribution: Von Mises

vonmises = np.random.vonmises(0, 1, 100)
plt.hist(vonmises)
vonmises_mean = np.mean(vonmises)
vonmises_std = np.std(vonmises)
print("Mean:", vonmises_mean)
print("Standard Deviation:", vonmises_std)

plt.hist(vonmises, color='blue')
plt.axvline(x=vonmises_mean, color='red')
plt.axvline(x=vonmises_mean+vonmises_std, color='yellow')
plt.axvline(x=vonmises_mean-vonmises_std, color='yellow')
vonmises_pd = pd.DataFrame(vonmises)
vonmises_pd.describe()
plt.show()
# Out:
# Mean: -0.11210523926577362
# Standard Deviation: 1.2529695808330379

# %%
norm1 = np.random.normal(5, 0.5, 1000)
norm2 = np.random.normal(10, 1, 1000)
norm3 = norm1 + norm2
plt.hist(norm3)
norm3_mean = np.mean(norm3)
norm3_std = np.std(norm3)
print("Mean:", norm3_mean)
print("Standard Deviation:", norm3_std)
plt.axvline(x=norm3_mean, color='red')
plt.axvline(x=norm3_mean+norm3_std, color='yellow')
plt.axvline(x=norm3_mean-norm3_std, color='yellow')
norm3_pd = pd.DataFrame(norm3)
norm3_pd.describe()
plt.show()
# Out:
# Mean: 15.01953939075712
# Standard Deviation: 1.1247438500703724
